# %% [markdown]
# # Principal Component Analysis (PCA)

# %%
import numpy as np
from matplotlib import pyplot
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
def fn(x):
  r = np.random.uniform(-5, 5)
  return 0.5 * x + 50 + r

# %% [markdown]
# ## Create Data

# %%
x0 = np.random.uniform(low=0, high=50, size=100)
x1 = np.random.uniform(low=150, high=200, size=100)
x = np.array([*x0, *x1]).reshape(-1, 1)
y = np.vectorize(fn)(x)

X = np.hstack((x, y))
X[:10]
# Out:
# array([[40.38082775, 70.84886537],
#        [ 1.2576986 , 46.75966448],
#        [ 3.16195826, 52.94129282],
#        [41.74655021, 67.96302622],
#        [47.89511761, 73.58812833],
#        [46.26870974, 73.3722088 ],
#        [33.62748781, 66.66537826],
#        [11.6102487 , 53.25712532],
#        [ 0.57072652, 54.59035453],
#        [ 8.50885645, 50.7668595 ]])

# %%
pyplot.scatter(X[:, 0], X[:, 1])

# %% [markdown]
# ## Transform Data

# %%
data_scaled = StandardScaler().fit_transform(X)
result = PCA(n_components=1).fit_transform(data_scaled)

# %%
pyplot.scatter(result[:, 0], np.zeros(result.shape))
